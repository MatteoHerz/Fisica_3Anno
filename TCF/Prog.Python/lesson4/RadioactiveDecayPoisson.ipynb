# %%
# %matplotlib qt
# Out:
# N_nuclei left =  200000
# /var/folders/bj/08q887vj56ndq4sf5d6dj2d80000gn/T/ipykernel_6454/1595670328.py:44: UserWarning: Attempting to set identical low and high ylims makes transformation singular; automatically expanding.
#   ax_top.set_ylim(0., max(n_decays)*1.1)
# N_nuclei left =  199996
# N_nuclei left =  199988
# N_nuclei left =  199985
# N_nuclei left =  199981
# N_nuclei left =  199978
# N_nuclei left =  199978
# N_nuclei left =  199974
# N_nuclei left =  199974
# N_nuclei left =  199973
# N_nuclei left =  199971
# N_nuclei left =  199969
# N_nuclei left =  199967
# N_nuclei left =  199966
# N_nuclei left =  199963
# N_nuclei left =  199961
# N_nuclei left =  199960
# N_nuclei left =  199959
# N_nuclei left =  199954
# N_nuclei left =  199951
# N_nuclei left =  199950
# N_nuclei left =  199950
# N_nuclei left =  199947
# N_nuclei left =  199945
# N_nuclei left =  199941
# N_nuclei left =  199940
# N_nuclei left =  199936
# N_nuclei left =  199932
# N_nuclei left =  199929
# N_nuclei left =  199927
# N_nuclei left =  199924
# N_nuclei left =  199919
# N_nuclei left =  199918
# N_nuclei left =  199918
# N_nuclei left =  199918
# N_nuclei left =  199914
# N_nuclei left =  199911
# N_nuclei left =  199907
# N_nuclei left =  199905
# N_nuclei left =  199901
# N_nuclei left =  199899
# N_nuclei left =  199896
# N_nuclei left =  199895
# N_nuclei left =  199893
# N_nuclei left =  199891
# N_nuclei left =  199887
# N_nuclei left =  199885
# N_nuclei left =  199884
# N_nuclei left =  199881
# N_nuclei left =  199879
# N_nuclei left =  199875
# N_nuclei left =  199871
# N_nuclei left =  199870
# N_nuclei left =  199868
# N_nuclei left =  199866
# N_nuclei left =  199862
# N_nuclei left =  199862
# N_nuclei left =  199861
# N_nuclei left =  199858
# N_nuclei left =  199857
# N_nuclei left =  199854
# N_nuclei left =  199853
# N_nuclei left =  199853
# N_nuclei left =  199850
# N_nuclei left =  199849
# N_nuclei left =  199847
# N_nuclei left =  199846
# N_nuclei left =  199843
# N_nuclei left =  199841
# N_nuclei left =  199841
# N_nuclei left =  199837
# N_nuclei left =  199836
# N_nuclei left =  199835
# N_nuclei left =  199834
# N_nuclei left =  199830
# N_nuclei left =  199830
# N_nuclei left =  199827
# N_nuclei left =  199827
# N_nuclei left =  199823
# N_nuclei left =  199822
# N_nuclei left =  199822
# N_nuclei left =  199820
# N_nuclei left =  199817
# N_nuclei left =  199814
# N_nuclei left =  199811
# N_nuclei left =  199810
# N_nuclei left =  199807
# N_nuclei left =  199803
# N_nuclei left =  199799
# N_nuclei left =  199796
# N_nuclei left =  199791
# N_nuclei left =  199790
# N_nuclei left =  199789
# N_nuclei left =  199785
# N_nuclei left =  199781
# N_nuclei left =  199781
# N_nuclei left =  199779
# N_nuclei left =  199775
# N_nuclei left =  199773
# N_nuclei left =  199770
# N_nuclei left =  199769
# N_nuclei left =  199768
# N_nuclei left =  199765
# N_nuclei left =  199764
# N_nuclei left =  199762
# N_nuclei left =  199757
# N_nuclei left =  199754
# N_nuclei left =  199754
# N_nuclei left =  199752
# N_nuclei left =  199750
# N_nuclei left =  199747
# N_nuclei left =  199746
# N_nuclei left =  199744
# N_nuclei left =  199738
# N_nuclei left =  199737
# N_nuclei left =  199735
# N_nuclei left =  199734
# N_nuclei left =  199733
# N_nuclei left =  199731
# N_nuclei left =  199729
# N_nuclei left =  199726
# N_nuclei left =  199723
# N_nuclei left =  199717
# N_nuclei left =  199715
# N_nuclei left =  199713
# N_nuclei left =  199711
# N_nuclei left =  199710
# N_nuclei left =  199707
# N_nuclei left =  199706
# N_nuclei left =  199705
# N_nuclei left =  199701
# N_nuclei left =  199700
# N_nuclei left =  199699
# N_nuclei left =  199699
# N_nuclei left =  199698
# N_nuclei left =  199696
# N_nuclei left =  199694
# N_nuclei left =  199692
# N_nuclei left =  199690
# N_nuclei left =  199689
# N_nuclei left =  199686
# N_nuclei left =  199684
# N_nuclei left =  199681
# N_nuclei left =  199679
# N_nuclei left =  199676
# N_nuclei left =  199675
# N_nuclei left =  199674
# N_nuclei left =  199672
# N_nuclei left =  199671
# N_nuclei left =  199667
# N_nuclei left =  199665
# N_nuclei left =  199663
# N_nuclei left =  199660
# N_nuclei left =  199658
# N_nuclei left =  199658
# N_nuclei left =  199654
# N_nuclei left =  199653
# N_nuclei left =  199653
# N_nuclei left =  199653
# N_nuclei left =  199651
# N_nuclei left =  199646
# N_nuclei left =  199645
# N_nuclei left =  199642
# N_nuclei left =  199641
# N_nuclei left =  199640
# N_nuclei left =  199640
# N_nuclei left =  199636
# N_nuclei left =  199633
# N_nuclei left =  199629
# N_nuclei left =  199628
# N_nuclei left =  199628
# N_nuclei left =  199627
# N_nuclei left =  199626
# N_nuclei left =  199623
# N_nuclei left =  199621
# N_nuclei left =  199618
# N_nuclei left =  199615
# N_nuclei left =  199614
# N_nuclei left =  199613
# N_nuclei left =  199610
# N_nuclei left =  199610
# N_nuclei left =  199608
# N_nuclei left =  199605
# N_nuclei left =  199604
# N_nuclei left =  199603
# N_nuclei left =  199603
# N_nuclei left =  199602
# N_nuclei left =  199602
# N_nuclei left =  199598
# N_nuclei left =  199598
# N_nuclei left =  199597
# N_nuclei left =  199595
# N_nuclei left =  199595
# N_nuclei left =  199589
# N_nuclei left =  199589
# N_nuclei left =  199584
# N_nuclei left =  199581
# N_nuclei left =  199576
# N_nuclei left =  199573
# N_nuclei left =  199572
# N_nuclei left =  199571
# N_nuclei left =  199570
# N_nuclei left =  199568
# N_nuclei left =  199564
# N_nuclei left =  199564
# N_nuclei left =  199562
# N_nuclei left =  199561
# N_nuclei left =  199559
# N_nuclei left =  199556
# N_nuclei left =  199553
# N_nuclei left =  199550
# N_nuclei left =  199547
# N_nuclei left =  199547
# N_nuclei left =  199547
# N_nuclei left =  199546
# N_nuclei left =  199544
# N_nuclei left =  199542
# N_nuclei left =  199542
# N_nuclei left =  199542
# N_nuclei left =  199539
# N_nuclei left =  199536
# N_nuclei left =  199534
# N_nuclei left =  199531
# N_nuclei left =  199526
# N_nuclei left =  199522
# N_nuclei left =  199521
# N_nuclei left =  199520
# N_nuclei left =  199517
# N_nuclei left =  199515
# N_nuclei left =  199514
# N_nuclei left =  199510
# N_nuclei left =  199508
# N_nuclei left =  199507
# N_nuclei left =  199504
# N_nuclei left =  199502
# N_nuclei left =  199500
# N_nuclei left =  199500
# N_nuclei left =  199499
# N_nuclei left =  199498
# N_nuclei left =  199494
# N_nuclei left =  199489
# N_nuclei left =  199489
# N_nuclei left =  199487
# N_nuclei left =  199483
# N_nuclei left =  199479
# N_nuclei left =  199476
# N_nuclei left =  199476
# N_nuclei left =  199475
# N_nuclei left =  199473
# N_nuclei left =  199473
# N_nuclei left =  199472
# N_nuclei left =  199468
# N_nuclei left =  199462
# N_nuclei left =  199456
# N_nuclei left =  199451
# N_nuclei left =  199446
# N_nuclei left =  199444
# N_nuclei left =  199438
# N_nuclei left =  199435
# N_nuclei left =  199434
# N_nuclei left =  199431
# N_nuclei left =  199430
# N_nuclei left =  199428
# N_nuclei left =  199424
# N_nuclei left =  199420
# N_nuclei left =  199419
# N_nuclei left =  199419
# N_nuclei left =  199417
# N_nuclei left =  199412
# N_nuclei left =  199411
# N_nuclei left =  199409
# N_nuclei left =  199408
# N_nuclei left =  199405
# N_nuclei left =  199405
# N_nuclei left =  199402
# N_nuclei left =  199399
# N_nuclei left =  199395
# N_nuclei left =  199391
# N_nuclei left =  199389
# N_nuclei left =  199386
# N_nuclei left =  199386
# N_nuclei left =  199385
# N_nuclei left =  199384
# N_nuclei left =  199381
# N_nuclei left =  199381
# N_nuclei left =  199379
# N_nuclei left =  199378
# N_nuclei left =  199377
# N_nuclei left =  199374
# N_nuclei left =  199374
# N_nuclei left =  199373
# N_nuclei left =  199372
# N_nuclei left =  199370
# N_nuclei left =  199369
# N_nuclei left =  199368
# N_nuclei left =  199365
# N_nuclei left =  199361
# N_nuclei left =  199359
# N_nuclei left =  199359
# N_nuclei left =  199356
# N_nuclei left =  199354
# N_nuclei left =  199352
# N_nuclei left =  199349
# N_nuclei left =  199346
# N_nuclei left =  199344
# N_nuclei left =  199342
# N_nuclei left =  199341
# N_nuclei left =  199337
# N_nuclei left =  199335
# N_nuclei left =  199332
# N_nuclei left =  199330
# N_nuclei left =  199329
# N_nuclei left =  199327
# N_nuclei left =  199326
# N_nuclei left =  199322
# N_nuclei left =  199318
# N_nuclei left =  199313
# N_nuclei left =  199312
# N_nuclei left =  199311
# N_nuclei left =  199308
# N_nuclei left =  199307
# N_nuclei left =  199304
# N_nuclei left =  199303
# N_nuclei left =  199303
# N_nuclei left =  199301
# N_nuclei left =  199299
# N_nuclei left =  199299
# N_nuclei left =  199295
# N_nuclei left =  199293
# N_nuclei left =  199292
# N_nuclei left =  199289
# N_nuclei left =  199288
# N_nuclei left =  199285
# N_nuclei left =  199283
# N_nuclei left =  199281
# N_nuclei left =  199277
# N_nuclei left =  199277
# N_nuclei left =  199274
# N_nuclei left =  199265
# N_nuclei left =  199262
# N_nuclei left =  199257
# N_nuclei left =  199253
# N_nuclei left =  199250
# N_nuclei left =  199247
# N_nuclei left =  199245
# N_nuclei left =  199241
# N_nuclei left =  199240
# N_nuclei left =  199236
# N_nuclei left =  199234
# N_nuclei left =  199231
# N_nuclei left =  199229
# N_nuclei left =  199224
# N_nuclei left =  199223
# N_nuclei left =  199223
# N_nuclei left =  199222
# N_nuclei left =  199221
# N_nuclei left =  199220
# N_nuclei left =  199219
# N_nuclei left =  199218
# N_nuclei left =  199215
# N_nuclei left =  199213
# N_nuclei left =  199206
# N_nuclei left =  199201
# N_nuclei left =  199196
# N_nuclei left =  199194
# N_nuclei left =  199191

# %%
"""Dynamically graphing frequencies of radioactive decays."""
#import matplotlib
#matplotlib.use('TkAgg')
from matplotlib import animation
import matplotlib.pyplot as plt
import random 
import math
from scipy.stats import poisson

# number of animation frames
number_of_frames = 1000 

# radioactive-isotope half-life
half_life = 88_300  # in minutes
# half_life = 155  # in minutes

# number of radioactive-isotope nuclei 
n0_nuclei = 200_000

def init(): 
    global n_nuclei
    n_nuclei = n0_nuclei

def update(frame_number, n_decays, poisson_freq, frequencies):
    """Configures bar plots contents for each animation frame."""
    global n_nuclei
    # simulate number of nuclei decayed between t and t + Deltat
    n_decays_in_time = [random.uniform(0.,1.) < 1-math.exp(-1./half_life) for i in range(n_nuclei)].count(True)
    n_decays[frame_number] = n_decays_in_time
    n_nuclei -= n_decays_in_time
    print ("N_nuclei left = ", n_nuclei)
    
    # generate frequencies
    if (n_decays_in_time < len(frequencies)) :
        frequencies[n_decays_in_time] += 1

    # generate Poisson
    mu = n0_nuclei/half_life
    for ipois in range(len(poisson_freq)) :
        poisson_freq[ipois] = frame_number * poisson.pmf(ipois,mu)
    
    for bars, h in zip(ndecay_vs_time,n_decays):
        bars.set_height(h)
    ax_top.set_ylim(0., max(n_decays)*1.1)    
    for bars2, h2 in zip(frequency_of_ndecay,frequencies):
        bars2.set_height(h2)
    ax_bottom.set_ylim(0., max(frequencies)*1.1)
    for bars3, h3 in zip(poisson_frequency,poisson_freq):
        bars3.set_height(h3)

# Ndecays vs. time plot
times    = list(range(number_of_frames))    # 1000 one-minute consecutive intervals
n_decays = [0.] * number_of_frames          # number of decayed nuclei in interval i

# frequency of Ndecays
max_freq = min(500, 4 * n0_nuclei // half_life)
n_decays_value = list(range(max_freq))              # possible ndecays values, conservatively up to 4*average (average = N_nuclei * Delta t/tau)  
frequencies   = [0] * max_freq                      # frequency of occurrence of one specific ndecays value
poisson_freq  = [0] * max_freq                      # Poisson occurrence of one specific ndecays value

figure = plt.figure(figsize=(6,8))
ax_top = figure.add_subplot(211)
ndecay_vs_time = ax_top.bar(times,n_decays)
ax_top.grid(True)
ax_top.set_xlabel('Time interval [min]')
ax_top.set_ylabel('Decayed nuclei in time interval')
ax_top.set_title('Radioactive decays')

ax_bottom = figure.add_subplot(212)
frequency_of_ndecay = ax_bottom.bar(n_decays_value,frequencies,alpha=0.5) 
poisson_frequency   = ax_bottom.bar(n_decays_value,poisson_freq,alpha=0.5) 
ax_bottom.grid(True)
ax_bottom.set_xlabel('Decayed nuclei in time interval')
ax_bottom.set_ylabel('Frequency')

# configure and start animation that calls function update
rd_animation = animation.FuncAnimation(
    figure, update, init_func=init, repeat=False, frames=number_of_frames,
    fargs=(n_decays, poisson_freq, frequencies))

plt.show()  # display window
